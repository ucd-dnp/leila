# %% [markdown]
# # Módulo datos_gov - LEILA
# Este libro de Jupyter contiene ejemplos con explicaciones de cómo utilizar el módulo que conecta a un usuario con el Portal de Datos Abiertos de Colombia

# %% [markdown]
# ### Importar la clase DatosGov del módulo datos_gov
# <!-- Importar la clase DatosGov del módulo datos_gov de LEILA. Con esta clase se podrá buscar información que esté publicada en el Portal de Datos Abiertos -->

# %%
from leila.datos_gov import DatosGov

# %% [markdown]
# Se importa la tabla de inventario de datos.gov.co. Esta tabla contiene todas las publicaciones del Portal (conjuntos de datos, enlaces externos, mapas, gráficos, etc.).

# %%
inventario = DatosGov().tabla_inventario()

# %% [markdown]
# Las columnas de la tabla de inventario son las siguientes:
#
# "**numero_api**": número API del conjunto de datos. Este es un carácter único de cada conjunto de datos del Portal que se usa como insumo para abrirlo desde código.
#
# "**nombre**": nombre de la publicación
#
# "**descripcion**": descripción de la publicación
#
# "**dueno**": dueño de la publicación.
#
# "**base_publica**": indica con un "si" si la información del conjunto de datos es público y con un "no" de lo contrario
#
# "**tipo**": indica el tipo de la publicación, que puede ser uno de los siguientes: "conjunto de datos", "enlace externo", "mapa", "grafico", "vista filtrada", "archivo o documento", "historia", "visualizacion", "lente de datos", "formulario", "calendario".
#
# "**categoria**": tema general del que trata la información publicada
#
# "**terminos_clave**": términos clave relacionados con la publicación
#
# "**url**": enlace web de la publicación en el Portal de Datos Abiertos
#
# "**fecha_creacion**": fecha de creación de la publicación
#
# "**fecha_actualizacion**": última fecha de actualización de la publicación
#
# "**filas**": número de filas del conjunto de datos, si aplica
#
# "**columnas**": número de columnas del conjunto de datos, si aplica
#
# "**correo_contacto**": correo de contacto de la entidad dueña de los datos
#
# "**licencia**": nombre de la licencia los datos
#
# "**entidad**": nombre de la entidad dueña de los datos
#
# "**entidad_url**": enlace web de la entidad dueña de los datos
#
# "**entidad_sector**": sector de la entidad
#
# "**entidad_departamento**": departamento de la entidad
#
# "**entidad_orden**": especifica si publicación es de orden territorial, nacional, departamental o internacional
#
# "**entidad_dependencia**": dependencia de la entidad dueña de los datos
#
# "**entidad_municipio**": municipio donde opera la entidad
#
# "**actualizacion_frecuencia**": frecuencia de actualización de los datos. Puede ser anual, semestral, mensual, trimestral, trianual, diaria, quinquenal, semanal, entre otros. También puede no aplicar
#
# "**idioma**": idioma en el que se encuentra la información
#
# "**cobertura**": alcance de la información. Puede ser nacional, departamental, municipal, centro poblado o internacional

# %% [markdown]
# ### Filtrar la tabla de inventario

# %% [markdown]
# Es posible buscar información de interés dentro de la tabla de inventario. La búsqueda se hace a partir de términos o texto que puede ser buscado en las columnas de formato texto de la tabla de inventario, por un rango de fechas o por el número filas o columnas.

# %% [markdown]
# #### Ejemplo: búsqueda por términos clave
#
# Para hacer la búsqueda por términos clave, se construye un diccionario de Python que contenga como llaves los nombres de las columnas de texto de la tabla de inventario sobre las cuales se desea hacer el filtro. Los valores de cada llave es una lista que contiene uno o más términos clave. Este diccionario se ingresa al método "tabla_inventario" de DatosGov dentro del parámetro "filtro".
#
# Los términos que se ingresan al diccionario no tienen que tener tildes o mayúsculas que se encuentran en la columna original de la tabla de inventario. Por ejemplo, los resultados serán los mismos si se buscan las palabras "Economía", "economía", "economia" o "ECONOMÍA".
#
# Abajo se encuentra un ejemplo donde se filtra la tabla de inventario por las columnas "nombre" y "tipo". Dentro de la columna "nombre" se busca si contiene los términos "economia" o "ambiente" y si la columna "tipo" contiene el término "conjunto de datos". Es decir, se están buscando conjuntos de datos de temas de economía o ambiente.

# %%
# Se crea el diccionario con el filtro deseado
filtro = {
    "nombre": ["economia", "ambiente"],
    "tipo": ["conjunto de datos"]
}

# Se abre la tabla de inventario con el filtro deseado
inventario = DatosGov().tabla_inventario(filtro=filtro)

# %%
# Se imprime la tabla de inventario con el filtro aplicado en la celda anterior
inventario
# Out:
#         numero_api                                             nombre  \
# 4331     8w5c-54ny                             Economía del municipio
# 5839     j7br-6yvm                            Contactos Sec. Ambiente
# 9952     bgmv-gnda                           AMBIENTE FÍSICO ANIMALES
# 9982     8ffd-q6x9                                           AMBIENTE
# 17209    rm5b-5f33                                    AMBIENTE FISICO
# 22681  8ffd-q6x9:0                                           AMBIENTE
# 33255    q282-rcj5                          Sector Economía Solidaria
# 34615    fwsu-jxw6  RELACION PROTOCOLOS DE BIOSEGURIDAD SECTORES D...
# 34628    3bvi-vpkx  Indicadores de Economía y Productividad de Sab...
#
#                                              descripcion  \
# 4331   La principal base de la economía del Municipio...
# 5839   Contactos en el departamento del Tolima para e...
# 9952   Caracterización de viviendas estrategia APS (a...
# 9982   La consolidación de temas ambientales en el mu...
# 17209  Caracterización de viviendas estrategia APS (a...
# 22681  La consolidación de temas ambientales en el mu...
# 33255  Registros de entidades pertenecientes al secto...
# 34615  RELACION PROTOCOLOS DE BIOSEGURIDAD SECTORES D...
# 34628  Conozca indicadores de economía y productivida...
#
#                                                    dueno base_publica  \
# 4331                                  Alcaldía Guatavita           Si
# 5839                      Carlos Alberto Sanchez Alfonso           Si
# 9952                  Alcaldia de Pereira Secretaria TIC           Si
# 9982                                 ALCALDIADEPALESTINA           Si
# 17209                 Alcaldia de Pereira Secretaria TIC           Si
# 22681                                ALCALDIADEPALESTINA           No
# 33255  Cámara de Comercio de Valledupar para el Valle...           Si
# 34615                                     alcaldiarovira           Si
# 34628                               Alcaldía de Sabaneta           Si
#
#                     tipo                         categoria  \
# 4331   conjunto de datos               Economía y Finanzas
# 5839   conjunto de datos  Ambiente y Desarrollo Sostenible
# 9952   conjunto de datos         Salud y Protección Social
# 9982   conjunto de datos  Ambiente y Desarrollo Sostenible
# 17209  conjunto de datos         Salud y Protección Social
# 22681  conjunto de datos  Ambiente y Desarrollo Sostenible
# 33255  conjunto de datos                               NaN
# 34615  conjunto de datos         Salud y Protección Social
# 34628  conjunto de datos               Economía y Finanzas
#
#                                           terminos_clave  \
# 4331                                                 NaN
# 5839                gobernacion,tolima,ambiente,contacto
# 9952                                                 NaN
# 9982                                            ambiente
# 17209                                                NaN
# 22681                                           ambiente
# 33255                                 economía solidaria
# 34615                     bioseguridad,rovira,protocolos
# 34628  mercado laboral,comercio,economia,industria,in...
#
#                                                     url      fecha_creacion  \
# 4331               https://www.datos.gov.co/d/8w5c-54ny 2018-09-28 20:35:26
# 5839               https://www.datos.gov.co/d/j7br-6yvm 2016-12-12 16:42:03
# 9952               https://www.datos.gov.co/d/bgmv-gnda 2019-12-03 13:28:54
# 9982               https://www.datos.gov.co/d/8ffd-q6x9 2018-07-12 16:56:38
# 17209              https://www.datos.gov.co/d/rm5b-5f33 2019-12-03 13:37:29
# 22681  https://www.datos.gov.co/d/8ffd-q6x9/revisions/0 2021-03-04 14:43:12
# 33255              https://www.datos.gov.co/d/q282-rcj5 2020-11-04 16:01:05
# 34615              https://www.datos.gov.co/d/fwsu-jxw6 2020-10-21 21:39:17
# 34628              https://www.datos.gov.co/d/3bvi-vpkx 2018-10-02 14:50:36
#
#        ...                                            entidad  \
# 4331   ...                                                NaN
# 5839   ...                             Gobernacion del Tolima
# 9952   ...                                Alcaldia de Pereira
# 9982   ...                                                NaN
# 17209  ...                                Alcaldia de Pereira
# 22681  ...                                                NaN
# 33255  ...  Cámara de Comercio de Valledupar para el Valle...
# 34615  ...                                 ALCALDIA DE ROVIRA
# 34628  ...                               Alcaldía de Sabaneta
#
#                                              entidad_url  \
# 4331                                                 NaN
# 5839                                                 NaN
# 9952                                                 NaN
# 9982                                                 NaN
# 17209                                                NaN
# 22681                                                NaN
# 33255                       https://ccvalledupar.org.co/
# 34615                                                NaN
# 34628  http://www.otsabaneta.org/economia-y-productiv...
#
#                          entidad_sector entidad_departamento entidad_orden  \
# 4331     Agricultura y Desarrollo Rural         Cundinamarca   Territorial
# 5839   Ambiente y Desarrollo Sostenible               Tolima   Territorial
# 9952          Salud y Protección Social            Risaralda   Territorial
# 9982   Ambiente y Desarrollo Sostenible               Caldas   Territorial
# 17209         Salud y Protección Social            Risaralda   Territorial
# 22681  Ambiente y Desarrollo Sostenible               Caldas   Territorial
# 33255                         No Aplica                Cesar   Territorial
# 34615                         No Aplica               Tolima   Territorial
# 34628                         No Aplica            Antioquia   Territorial
#
#                                      entidad_dependencia entidad_municipio  \
# 4331                               Desarrollo económico          Guatavita
# 5839   Secretaría del Ambiente y Gestión Riesgo del T...            Ibagué
# 9952                                 Secretaria de Salud           Pereira
# 9982                                          PLANEACION         Palestina
# 17209                                Secretaria de Salud           Pereira
# 22681                                         PLANEACION         Palestina
# 33255                                Registros Públicos         Valledupar
# 34615                               SECRETARIA DE SALUD             Rovira
# 34628  Secretaría de Planeación y Desarrollo Territor...          Sabaneta
#
#       actualizacion_frecuencia   idioma      cobertura
# 4331                 No aplica  Español      Municipal
# 5839                     Anual  Español  Departamental
# 9952                     Anual  Español      Municipal
# 9982                     Anual  Español      Municipal
# 17209                    Anual  Español      Municipal
# 22681                    Anual  Español      Municipal
# 33255                No aplica  Español  Departamental
# 34615                    Anual  Español      Municipal
# 34628                    Anual  Español      Municipal
#
# [9 rows x 25 columns]

# %% [markdown]
# #### Ejemplo: búsqueda por rango de filas y columnas
#
# Para hacer el filtro de la tabla de inventario por el tamaño de un conjunto de datos, se tiene que incluir el nombre de las columnas "filas" y "columnas" en el diccionario. Los valores de estas llaves son listas con dos elementos cada una: el primer elemento es el valor mínimo de filas o columnas y el segundo el valor máximo.
#
# A continuación se muestra un ejemplo de filtro, donde se seleccionan los conjuntos de datos con mínimo 50 filas y máximo 60 y con mínimo 8 columnas y máximo 10

# %%
# Se crea el diccionario con el filtro deseado
filtro = {
    "filas": [50, 60],
    "columnas": [8, 10]
}

# Se abre la tabla de inventario con el filtro deseado
inventario = DatosGov().tabla_inventario(filtro=filtro)

# %%
# Imprimir las columnas del código API, nombre, descripción, filas y columnas de la tabla de inventario filtrada
inventario[["numero_api", "nombre", "descripcion", "filas", "columnas"]]
# Out:
#       numero_api                                             nombre  \
# 55     igcu-56c4  CONTRATOS PRESTACION DE SERVICIOS  2018  MUNIC...
# 326    e9d5-9xvt  Instituciones Educativas Extintas del Municipi...
# 367    vxhy-86k4             Ejecución Presupuestal a Junio de 2017
# 421    hysn-yquu  Publicidad registro de vallas  Municipio de Pa...
# 519    8qip-sek5  Corregidores y Auxiliares Corregidores del Mun...
# ...          ...                                                ...
# 34281  svz2-ug32                Contratistas Alcaldía Mistrató 2021
# 34628  3bvi-vpkx  Indicadores de Economía y Productividad de Sab...
# 34739  symc-8gre                         DOCENTES POR GENERO 2019-2
# 34759  rubk-nymq     Correos Institucionales Alcaldía de Copacabana
# 34808  9m2f-pdxx  Licencias de Cannabis otorgadas por el Ministe...
#
#                                              descripcion  filas  columnas
# 55     Lista  contratos de prestación de servicio  al...   57.0      10.0
# 326    Información de las Instituciones Educativas qu...   58.0      10.0
# 367    Acumulado de la ejecución presupuestal de la U...   56.0       9.0
# 421    Registro de vallas publicitarias del Municipio...   53.0       8.0
# 519    Corregidores y Auxiliares o Ayudantes de Corre...   54.0       9.0
# ...                                                  ...    ...       ...
# 34281  Contiene datos del contratista como nombres y ...   50.0       9.0
# 34628  Conozca indicadores de economía y productivida...   57.0      10.0
# 34739  Docentes de planta, contrato y catedráticos cl...   59.0       8.0
# 34759  Correos institucionales del municipio de Copac...   54.0       8.0
# 34808  Licencias de uso de semillas para siembra, de ...   56.0      10.0
#
# [101 rows x 5 columns]

# %% [markdown]
# #### Ejemplo: búsqueda por fecha

# %% [markdown]
# La tabla de inventario también puede filtrase por fecha. Para hacerlo, se ingresa el diccionario de filtro con una de las columnas de fecha y se especifican las fechas de inicio y de fin deseadas. El siguiente ejemplo muestra cómo obtener la tabla de inventario para publicaciones creadas entre el 1 de enero de 2020 y el 1 de febrero de 2020.

# %%
# Se crea el diccionario con el filtro deseado
filtro = {
    "fecha_creacion": ["2020-01-01", "2020-02-01"],
}

# Se abre la tabla de inventario con el filtro deseado
inventario = DatosGov().tabla_inventario(filtro=filtro)

# %%
# Se muestra la tabla filtrada por fecha
inventario
# Out:
#         numero_api                                             nombre  \
# 104    k2sw-5j93:2  Atención al usuario año 2020 Instituto Municip...
# 106      5ex4-dqe9  Población estudiantil posgrado por semestre y/...
# 331      wu3s-8hsw  Población estudiantil pregrado por programa y ...
# 498    6b2t-68uu:0            Entidades Públicas Municipio de El Hobo
# 549    88ru-5pzs:0                                    MORBILIDAD 2019
# ...            ...                                                ...
# 33666    ir4d-mzgr  Publicaciones_E_Interacciones_Campaña_#Evoluci...
# 34634    9et2-bf5i                                   Entrega y Retoma
# 34660    fnir-e2zx                                     DISCONTINUIDAD
# 34690    syiu-8mvf  PARQUE AUTOMOTOR  DEL MUNICIPIO DE BARBOSA ANT...
# 34780    etwv-wj8f            Pueblos indígenas a nivel Nacional 2020
#
#                                              descripcion  \
# 104    El ejercicio de caracterización de los usuario...
# 106    Población estudiantil posgrado por semestre y/...
# 331    Población estudiantil por programa y semestre ...
# 498                                                  NaN
# 549                                                  NaN
# ...                                                  ...
# 33666  La campaña #EvoluciónTransparente buscó conoce...
# 34634                                   Entrega y Retoma
# 34660                     DISCONTINUIDAD SEPTIEMBRE 2020
# 34690  Contiene el inventario de vehículos  registrad...
# 34780  Información de la ubicación de los pueblos ind...
#
#                                                    dueno base_publica  \
# 104                                                IMETY           No
# 106            Universidad Colegio Mayor de Cundinamarca           Si
# 331            Universidad Colegio Mayor de Cundinamarca           Si
# 498                                     Alcaldía de Hobo           No
# 549                                  Capacitacion Mintic           No
# ...                                                  ...          ...
# 33666                                      urnadecristal           Si
# 34634   Ministerio TIC Oficina TI Gestión de Informacion           Si
# 34660  EMPRESA IBAGUEREÑA DE ACUEDUCTO Y ALCANTARILLA...           Si
# 34690                    Alcaldía de Barbosa - Antioquia           Si
# 34780                            Ministerio del Interior           Si
#
#                     tipo                         categoria  \
# 104    conjunto de datos                         Educación
# 106    conjunto de datos                         Educación
# 331    conjunto de datos                         Educación
# 498    conjunto de datos                               NaN
# 549    conjunto de datos                               NaN
# ...                  ...                               ...
# 33666  conjunto de datos           Participación ciudadana
# 34634  conjunto de datos  Ciencia, Tecnología e Innovación
# 34660  conjunto de datos     Vivienda, Ciudad y Territorio
# 34690  conjunto de datos                        Transporte
# 34780  conjunto de datos                               NaN
#
#                                           terminos_clave  \
# 104                                                  NaN
# 106    programas académicos,posgrado,unicolmayor,univ...
# 331    estudiantes matriculados,programas académicos,...
# 498                                                  NaN
# 549                                                  NaN
# ...                                                  ...
# 33666                                                NaN
# 34634                                                NaN
# 34660                                                NaN
# 34690                         vehiculos,parque automotor
# 34780                     indígenas,dairm,etnias,pueblos
#
#                                                     url      fecha_creacion  \
# 104    https://www.datos.gov.co/d/k2sw-5j93/revisions/2 2020-01-23 19:49:39
# 106                https://www.datos.gov.co/d/5ex4-dqe9 2020-01-21 17:05:26
# 331                https://www.datos.gov.co/d/wu3s-8hsw 2020-01-21 15:35:30
# 498    https://www.datos.gov.co/d/6b2t-68uu/revisions/0 2020-01-03 15:55:41
# 549    https://www.datos.gov.co/d/88ru-5pzs/revisions/0 2020-01-02 16:12:57
# ...                                                 ...                 ...
# 33666              https://www.datos.gov.co/d/ir4d-mzgr 2020-01-17 15:35:23
# 34634              https://www.datos.gov.co/d/9et2-bf5i 2020-01-27 21:17:01
# 34660              https://www.datos.gov.co/d/fnir-e2zx 2020-01-29 20:39:14
# 34690              https://www.datos.gov.co/d/syiu-8mvf 2020-01-16 19:19:56
# 34780              https://www.datos.gov.co/d/etwv-wj8f 2020-01-27 14:47:31
#
#        ...                                            entidad  \
# 104    ...  Instituto Municipal de Educación para el Traba...
# 106    ...          Universidad Colegio Mayor de Cundinamarca
# 331    ...          Universidad Colegio Mayor de Cundinamarca
# 498    ...                                                NaN
# 549    ...                                                NaN
# ...    ...                                                ...
# 33666  ...                                    Urna de Cristal
# 34634  ...  Ministerio de Tecnologías de la Información y ...
# 34660  ...                                                NaN
# 34690  ...                                                NaN
# 34780  ...                            Ministerio del Interior
#
#                                              entidad_url  \
# 104                                                  NaN
# 106    http://www.unicolmayor.edu.co/portal/index.php...
# 331    http://www.unicolmayor.edu.co/portal/index.php...
# 498                                                  NaN
# 549                                                  NaN
# ...                                                  ...
# 33666                                                NaN
# 34634                  https://colombiatic.mintic.gov.co
# 34660                                                NaN
# 34690                                                NaN
# 34780                                                NaN
#
#                          entidad_sector entidad_departamento entidad_orden  \
# 104                           Educación      Valle del Cauca   Territorial
# 106                           Educación          Bogotá D.C.      Nacional
# 331                           Educación          Bogotá D.C.      Nacional
# 498                                 NaN                  NaN           NaN
# 549                                 NaN                  NaN           NaN
# ...                                 ...                  ...           ...
# 33666                         No Aplica          Bogotá D.C.      Nacional
# 34634  Ciencia, Tecnología e innovación          Bogotá D.C.      Nacional
# 34660      Vivienda Ciudad y Territorio               Tolima   Territorial
# 34690                        Transporte            Antioquia   Territorial
# 34780                          Interior          Bogotá D.C.      Nacional
#
#                                  entidad_dependencia entidad_municipio  \
# 104                              Matricula Academica             Yumbo
# 106     Oficina de Planeación, sistemas y desarrollo       Bogotá D.C.
# 331     Oficina de Planeación, sistemas y desarrollo       Bogotá D.C.
# 498                                              NaN               NaN
# 549                                              NaN               NaN
# ...                                              ...               ...
# 33666                                Urna de Cristal       Bogotá D.C.
# 34634             Dirección Computadores para Educar       Bogotá D.C.
# 34660                          GRUPO CALIDAD DE AGUA            Ibagué
# 34690                        Secretaría de Movilidad           Barbosa
# 34780  Dirección de Asuntos Indígenas ROM y Minorías       Bogotá D.C.
#
#       actualizacion_frecuencia   idioma      cobertura
# 104                      Anual  Español  Departamental
# 106                      Anual  Español       Nacional
# 331                      Anual  Español       Nacional
# 498                        NaN      NaN            NaN
# 549                        NaN      NaN            NaN
# ...                        ...      ...            ...
# 33666                No aplica  Español       Nacional
# 34634                  Mensual  Español       Nacional
# 34660                  Mensual  Español      Municipal
# 34690                    Anual  Español      Municipal
# 34780                    Anual  Español       Nacional
#
# [106 rows x 25 columns]

# %% [markdown]
# ### Abrir un conjunto de datos del Portal de Datos Abiertos

# %% [markdown]
# Para abrir un conjunto de datos.gov.co es necesario tener el código API de ese conjunto e ingresarlo al método "cargar_base" de la clase DatosGov. Con esta función se crea un objeto que contiene el dataframe y el diccionario de metadatos del conjunto, los cuales se pueden obtener con los métodos "to_dataframe" y "metadatos"
#
# Abajo está el código para cargar el conjunto de datos de "Pueblos indígenas a nivel Nacional 2020", el cual se encuentra en el último filtro de la tabla de inventario.

# %% [markdown]
# #### Cargar conjunto de datos con número API

# %%
# Se define la variable "numero_api", que contiene el número API del conjunto "Pueblos indígenas a nivel Nacional 2020"
numero_api = "etwv-wj8f"
# Se descarga la información del conjunto de datos en la variable "data" con el método "cargar_base". 
# Al parámetro "api_id" se asigna el número API y "limite_filas" especifica que únicamente se descargan 200 filas del conjunto
data = DatosGov().cargar_base(api_id = numero_api, limite_filas=200)

# %% [markdown]
# #### Obtener dataframe del conjunto de datos

# %%
# Se obtiene el dataframe del conjunto de datos con el método "to_dataframe"
datos = data.to_dataframe()
# Se visualiza una versión reducida del dataframe
datos
# Out:
#      unnamed_column     departamento  pueblos_indigenas
# 0               NaN         AMAZONAS           KAWIYARI
# 1               NaN         AMAZONAS              SIONA
# 2               NaN         AMAZONAS              YAGUA
# 3               NaN         AMAZONAS           BARASANO
# 4               NaN         AMAZONAS            LETUAMA
# ..              ...              ...                ...
# 195             NaN  VALLE DEL CAUCA       EMBERA CHAMI
# 196             NaN  VALLE DEL CAUCA  EPERARA SIAPIDARA
# 197             NaN  VALLE DEL CAUCA               NASA
# 198             NaN  VALLE DEL CAUCA              PASTO
# 199             NaN  VALLE DEL CAUCA            WAUNANN
#
# [200 rows x 3 columns]

# %% [markdown]
# #### Obtener diccionario de metadatos del conjunto de datos

# %%
# Los metadatos se obtienen con el método "metadatos" y se asignan a la variable "meta"
meta = data.metadatos()
# Se visualiza el diccionario de metadatos
meta
# Out:
# {'numero_api': 'etwv-wj8f',
#  'nombre': 'Pueblos indígenas a nivel Nacional 2020',
#  'descripcion': 'Información de la ubicación de los pueblos indígenas por departamento y municipio a 31 de Diciembre de 2020.',
#  'tipo': 'dataset',
#  'url': 'NA',
#  'categoria': 'NA',
#  'fecha_creacion': '2020-01-27',
#  'numero_vistas': 360,
#  'numero_descargas': 60,
#  'licencia': 'NA',
#  'fecha_publicacion': '2020-01-27',
#  'base_publica': 'published',
#  'fecha_actualizacion': '2021-01-26',
#  'numero_filas': 'NA',
#  'numero_columnas': 3,
#  'licencia_url': 'http://creativecommons.org/licenses/by-sa/4.0/legalcode',
#  'entidad': 'Ministerio del Interior',
#  'entidad_municipio': 'Bogotá D.C.',
#  'entidad_sector': 'Interior',
#  'entidad_departamento': 'Bogotá D.C.',
#  'entidad_orden': 'Nacional',
#  'entidad_dependencia': 'Dirección de Asuntos Indígenas ROM y Minorías',
#  'cobertura': 'Nacional',
#  'idioma': 'Español',
#  'frecuencia_actualizacion': 'Anual',
#  'dueno': 'Ministerio del Interior',
#  'columnas': {'Unnamed Column': {'tipo': 'text',
#    'descripcion': '',
#    'nombre_df': 'unnamed_column'},
#   'DEPARTAMENTO': {'tipo': 'text',
#    'descripcion': '',
#    'nombre_df': 'departamento'},
#   'PUEBLOS INDIGENAS': {'tipo': 'text',
#    'descripcion': '',
#    'nombre_df': 'pueblos_indigenas'}}}
