# %% [markdown]
# ### Código para correr leila localmente en jupyter
# **ruta_leila** se refiere a la ruta en la que está alojado el código de leila que contiene las carpetas: ejemplos, leila y recursos

# %%
import sys
ruta_leila = '/home/michel/Documents/dnp/leila/leila_desarrollo_indice_reporte_herencia/leila'
sys.path.insert(0, ruta_leila)

# %% [markdown]
# # Módulo datos_gov - LEILA
# Este libro de Jupyter contiene ejemplos con explicaciones de cómo utilizar el módulo que conecta a un usuario con el Portal de Datos Abiertos de Colombia

# %% [markdown]
# ### Importar la clase DatosGov del módulo datos_gov
# <!-- Importar la clase DatosGov del módulo datos_gov de LEILA. Con esta clase se podrá buscar información que esté publicada en el Portal de Datos Abiertos -->

# %%
from leila.datos_gov import DatosGov

# %% [markdown]
# Se importa la tabla de inventario de datos.gov.co. Esta tabla contiene todas las publicaciones del Portal (conjuntos de datos, enlaces externos, mapas, gráficos, etc.).

# %%
inventario = DatosGov().tabla_inventario()

# %% [markdown]
# Las columnas de la tabla de inventario son las siguientes:
#
# "**numero_api**": número API del conjunto de datos. Este es un carácter único de cada conjunto de datos del Portal que se usa como insumo para abrirlo desde código.
#
# "**nombre**": nombre de la publicación
#
# "**descripcion**": descripción de la publicación
#
# "**dueno**": dueño de la publicación.
#
# "**base_publica**": indica con un "si" si la información del conjunto de datos es público y con un "no" de lo contrario
#
# "**tipo**": indica el tipo de la publicación, que puede ser uno de los siguientes: "conjunto de datos", "enlace externo", "mapa", "grafico", "vista filtrada", "archivo o documento", "historia", "visualizacion", "lente de datos", "formulario", "calendario".
#
# "**categoria**": tema general del que trata la información publicada
#
# "**terminos_clave**": términos clave relacionados con la publicación
#
# "**url**": enlace web de la publicación en el Portal de Datos Abiertos
#
# "**fecha_creacion**": fecha de creación de la publicación
#
# "**fecha_actualizacion**": última fecha de actualización de la publicación
#
# "**filas**": número de filas del conjunto de datos, si aplica
#
# "**columnas**": número de columnas del conjunto de datos, si aplica
#
# "**correo_contacto**": correo de contacto de la entidad dueña de los datos
#
# "**licencia**": nombre de la licencia los datos
#
# "**entidad**": nombre de la entidad dueña de los datos
#
# "**entidad_url**": enlace web de la entidad dueña de los datos
#
# "**entidad_sector**": sector de la entidad
#
# "**entidad_departamento**": departamento de la entidad
#
# "**entidad_orden**": especifica si publicación es de orden territorial, nacional, departamental o internacional
#
# "**entidad_dependencia**": dependencia de la entidad dueña de los datos
#
# "**entidad_municipio**": municipio donde opera la entidad
#
# "**actualizacion_frecuencia**": frecuencia de actualización de los datos. Puede ser anual, semestral, mensual, trimestral, trianual, diaria, quinquenal, semanal, entre otros. También puede no aplicar
#
# "**idioma**": idioma en el que se encuentra la información
#
# "**cobertura**": alcance de la información. Puede ser nacional, departamental, municipal, centro poblado o internacional

# %% [markdown]
# ### Filtrar la tabla de inventario

# %% [markdown]
# Es posible buscar información de interés dentro de la tabla de inventario. La búsqueda se hace a partir de términos o texto que puede ser buscado en las columnas de formato texto de la tabla de inventario, por un rango de fechas o por el número filas o columnas.

# %% [markdown]
# #### Ejemplo: búsqueda por términos clave
#
# Para hacer la búsqueda por términos clave, se construye un diccionario de Python que contenga como llaves los nombres de las columnas de texto de la tabla de inventario sobre las cuales se desea hacer el filtro. Los valores de cada llave es una lista que contiene uno o más términos clave. Este diccionario se ingresa al método "tabla_inventario" de DatosGov dentro del parámetro "filtro".
#
# Los términos que se ingresan al diccionario no tienen que tener tildes o mayúsculas que se encuentran en la columna original de la tabla de inventario. Por ejemplo, los resultados serán los mismos si se buscan las palabras "Economía", "economía", "economia" o "ECONOMÍA".
#
# Abajo se encuentra un ejemplo donde se filtra la tabla de inventario por las columnas "nombre" y "tipo". Dentro de la columna "nombre" se busca si contiene los términos "economia" o "ambiente" y si la columna "tipo" contiene el término "conjunto de datos". Es decir, se están buscando conjuntos de datos de temas de economía o ambiente.

# %%
# Se crea el diccionario con el filtro deseado
filtro = {
    "nombre": ["economia", "ambiente"],
    "tipo": ["conjunto de datos"]
}

# Se abre la tabla de inventario con el filtro deseado
inventario = DatosGov().tabla_inventario(filtro=filtro)

# %%
# Se imprime la tabla de inventario con el filtro aplicado en la celda anterior
inventario
# Out:
#         numero_api                                             nombre  \
# 5401     j7br-6yvm                            Contactos Sec. Ambiente
# 5447     8w5c-54ny                             Economía del municipio
# 8379   vwxz-yqyb:0                         GESTIÓN DE AMBIENTE FÍSICO
# 11694    bgmv-gnda                           AMBIENTE FÍSICO ANIMALES
# 11893    8ffd-q6x9                                           AMBIENTE
# 16614    rm5b-5f33                                    AMBIENTE FISICO
# 21873    59f6-58a8  BD  JOVENES  DE AMBIENTE JURISDICCION DE  CORP...
# 23910    am4p-tz7w  Censo de Arbolado urbano en Ibagué-Sria Ambien...
# 27460  8ffd-q6x9:0                                           AMBIENTE
# 32259    9zck-qfvc                   DELITOS CONTRA EL MEDIO AMBIENTE
# 37341    q282-rcj5                          Sector Economía Solidaria
# 40070    fwsu-jxw6  RELACION PROTOCOLOS DE BIOSEGURIDAD SECTORES D...
# 40082    3bvi-vpkx  Indicadores de Economía y Productividad de Sab...
#
#                                              descripcion  \
# 5401   Contactos en el departamento del Tolima para e...
# 5447   La principal base de la economía del Municipio...
# 8379                                                 NaN
# 11694  Caracterización de viviendas estrategia APS (a...
# 11893  La consolidación de temas ambientales en el mu...
# 16614  Caracterización de viviendas estrategia APS (a...
# 21873  BD  JOVENES  DE AMBIENTE JURISDICCION DE  CORP...
# 23910    Censo de Arbolado urbano en la ciudad de Ibagué
# 27460  La consolidación de temas ambientales en el mu...
# 32259  Acciones que afectan los recursos naturales y ...
# 37341  Registros de entidades pertenecientes al secto...
# 40070  RELACION PROTOCOLOS DE BIOSEGURIDAD SECTORES D...
# 40082  Conozca indicadores de economía y productivida...
#
#                                                    dueno base_publica  \
# 5401                      Carlos Alberto Sanchez Alfonso           Si
# 5447                                  Alcaldía Guatavita           Si
# 8379        ESE HOSPITAL SAN FRANCISCO DE VILLA DE ELYVA           No
# 11694                 Alcaldia de Pereira Secretaria TIC           Si
# 11893                                ALCALDIADEPALESTINA           Si
# 16614                 Alcaldia de Pereira Secretaria TIC           Si
# 21873           CORPORACION AUTONOMA REGIONAL DEL GUAVIO           Si
# 23910                                         tic_ibague           Si
# 27460                                ALCALDIADEPALESTINA           No
# 32259                                            johalda           Si
# 37341  Cámara de Comercio de Valledupar para el Valle...           Si
# 40070                                     alcaldiarovira           Si
# 40082                               Alcaldía de Sabaneta           Si
#
#                     tipo                         categoria  \
# 5401   conjunto de datos  Ambiente y Desarrollo Sostenible
# 5447   conjunto de datos               Economía y Finanzas
# 8379   conjunto de datos                               NaN
# 11694  conjunto de datos         Salud y Protección Social
# 11893  conjunto de datos  Ambiente y Desarrollo Sostenible
# 16614  conjunto de datos         Salud y Protección Social
# 21873  conjunto de datos           Participación ciudadana
# 23910  conjunto de datos  Ambiente y Desarrollo Sostenible
# 27460  conjunto de datos  Ambiente y Desarrollo Sostenible
# 32259  conjunto de datos               Seguridad y Defensa
# 37341  conjunto de datos                               NaN
# 40070  conjunto de datos         Salud y Protección Social
# 40082  conjunto de datos               Economía y Finanzas
#
#                                           terminos_clave  \
# 5401                gobernacion,tolima,ambiente,contacto
# 5447                                                 NaN
# 8379                                                 NaN
# 11694                                                NaN
# 11893                                           ambiente
# 16614                                                NaN
# 21873                                                NaN
# 23910                                            arboles
# 27460                                           ambiente
# 32259      ecosistemas,medio ambiente,recursos naturales
# 37341                                 economía solidaria
# 40070                     bioseguridad,protocolos,rovira
# 40082  tecnología,industria,economia,ciencia,comercio...
#
#                                                     url      fecha_creacion  \
# 5401               https://www.datos.gov.co/d/j7br-6yvm 2016-12-12 16:42:03
# 5447               https://www.datos.gov.co/d/8w5c-54ny 2018-09-28 20:35:26
# 8379   https://www.datos.gov.co/d/vwxz-yqyb/revisions/0 2022-09-29 18:17:56
# 11694              https://www.datos.gov.co/d/bgmv-gnda 2019-12-03 13:28:54
# 11893              https://www.datos.gov.co/d/8ffd-q6x9 2018-07-12 16:56:38
# 16614              https://www.datos.gov.co/d/rm5b-5f33 2019-12-03 13:37:29
# 21873              https://www.datos.gov.co/d/59f6-58a8 2021-12-10 16:17:48
# 23910              https://www.datos.gov.co/d/am4p-tz7w 2022-02-25 20:04:49
# 27460  https://www.datos.gov.co/d/8ffd-q6x9/revisions/0 2021-03-04 14:43:12
# 32259              https://www.datos.gov.co/d/9zck-qfvc 2022-07-04 15:16:15
# 37341              https://www.datos.gov.co/d/q282-rcj5 2020-11-04 16:01:05
# 40070              https://www.datos.gov.co/d/fwsu-jxw6 2020-10-21 21:39:17
# 40082              https://www.datos.gov.co/d/3bvi-vpkx 2018-10-02 14:50:36
#
#        ...                                            entidad  \
# 5401   ...                             Gobernacion del Tolima
# 5447   ...                                                NaN
# 8379   ...                                                NaN
# 11694  ...                                Alcaldia de Pereira
# 11893  ...                                                NaN
# 16614  ...                                Alcaldia de Pereira
# 21873  ...  Gloria Mora -coordinador del Area Educación am...
# 23910  ...  Secretaria de Ambiente y Gestión del Riesgo de...
# 27460  ...                                                NaN
# 32259  ...                     Ministerio de Defensa Nacional
# 37341  ...  Cámara de Comercio de Valledupar para el Valle...
# 40070  ...                                 ALCALDIA DE ROVIRA
# 40082  ...                               Alcaldía de Sabaneta
#
#                                              entidad_url  \
# 5401                                                 NaN
# 5447                                                 NaN
# 8379                                                 NaN
# 11694               https://www.datos.gov.co/d/bgmv-gnda
# 11893               https://www.datos.gov.co/d/8ffd-q6x9
# 16614               https://www.datos.gov.co/d/rm5b-5f33
# 21873                                                NaN
# 23910               https://www.datos.gov.co/d/am4p-tz7w
# 27460               https://www.datos.gov.co/d/8ffd-q6x9
# 32259  https://www.mindefensa.gov.co/irj/portal/Minde...
# 37341                       https://ccvalledupar.org.co/
# 40070               https://www.datos.gov.co/d/fwsu-jxw6
# 40082  http://www.otsabaneta.org/economia-y-productiv...
#
#                          entidad_sector entidad_departamento entidad_orden  \
# 5401   Ambiente y Desarrollo Sostenible               Tolima   Territorial
# 5447     Agricultura y Desarrollo Rural         Cundinamarca   Territorial
# 8379                                NaN                  NaN           NaN
# 11694         Salud y Protección Social            Risaralda   Territorial
# 11893  Ambiente y Desarrollo Sostenible               Caldas   Territorial
# 16614         Salud y Protección Social            Risaralda   Territorial
# 21873                         Educación         Cundinamarca   Territorial
# 23910  Ambiente y Desarrollo Sostenible               Tolima   Territorial
# 27460  Ambiente y Desarrollo Sostenible               Caldas   Territorial
# 32259                           Defensa          Bogotá D.C.      Nacional
# 37341                         No Aplica                Cesar   Territorial
# 40070                         No Aplica               Tolima   Territorial
# 40082                         No Aplica            Antioquia   Territorial
#
#                                      entidad_dependencia entidad_municipio  \
# 5401   Secretaría del Ambiente y Gestión Riesgo del T...            Ibagué
# 5447                               Desarrollo económico          Guatavita
# 8379                                                 NaN               NaN
# 11694                                Secretaria de Salud           Pereira
# 11893                                         PLANEACION         Palestina
# 16614                                Secretaria de Salud           Pereira
# 21873                                EDUCACION AMBIENTAL           Gachala
# 23910  ALCALDIA DE IBAGUE -SECRETARIA DE AMBIENTE Y G...            Ibagué
# 27460                                         PLANEACION         Palestina
# 32259  Observatorio de Derechos Humanos y Defensa Nac...       Bogotá D.C.
# 37341                                Registros Públicos         Valledupar
# 40070                               SECRETARIA DE SALUD             Rovira
# 40082  Secretaría de Planeación y Desarrollo Territor...          Sabaneta
#
#       actualizacion_frecuencia   idioma      cobertura
# 5401                     Anual  Español  Departamental
# 5447                 No aplica  Español      Municipal
# 8379                       NaN      NaN            NaN
# 11694                    Anual  Español      Municipal
# 11893                    Anual  Español      Municipal
# 16614                    Anual  Español      Municipal
# 21873                Semestral  Español      Municipal
# 23910                    Anual  Español      Municipal
# 27460                    Anual  Español      Municipal
# 32259                  Mensual  Español       Nacional
# 37341                No aplica  Español  Departamental
# 40070                    Anual  Español      Municipal
# 40082                    Anual  Español      Municipal
#
# [13 rows x 25 columns]

# %% [markdown]
# #### Ejemplo: búsqueda por rango de filas y columnas
#
# Para hacer el filtro de la tabla de inventario por el tamaño de un conjunto de datos, se tiene que incluir el nombre de las columnas "filas" y "columnas" en el diccionario. Los valores de estas llaves son listas con dos elementos cada una: el primer elemento es el valor mínimo de filas o columnas y el segundo el valor máximo.
#
# A continuación se muestra un ejemplo de filtro, donde se seleccionan los conjuntos de datos con mínimo 50 filas y máximo 60 y con mínimo 8 columnas y máximo 10

# %%
# Se crea el diccionario con el filtro deseado
filtro = {
    "filas": [50, 60],
    "columnas": [8, 10]
}

# Se abre la tabla de inventario con el filtro deseado
inventario = DatosGov().tabla_inventario(filtro=filtro)

# %%
# Imprimir las columnas del código API, nombre, descripción, filas y columnas de la tabla de inventario filtrada
inventario[["numero_api", "nombre", "descripcion", "filas", "columnas"]]
# Out:
#       numero_api                                             nombre  \
# 36     pkzu-sphq  Publicaciones_E_Interacciones_Campaña_#UsoLosD...
# 148    tvjz-wwbs  ENTIDADES FINANCIERAS EN EL DEPARTAMENTO DEL P...
# 359    8qip-sek5  Corregidores y Auxiliares Corregidores del Mun...
# 530    jhsz-mybn             Zonas wifi de departamento de Casanare
# 826    hysn-yquu  Publicidad registro de vallas  Municipio de Pa...
# ...          ...                                                ...
# 39744  mqu6-d62c              Producción Agrícola Cota Cundinamarca
# 39798  3yyx-wdfi  Empresas Constructoras Registradas en Palmira ...
# 39835  symc-8gre                         DOCENTES POR GENERO 2019-2
# 40082  3bvi-vpkx  Indicadores de Economía y Productividad de Sab...
# 40085  th3y-5zw3            TARIFAS ACUEDUCTO Y ALCANTARILLADO 2021
#
#                                              descripcion  filas  columnas
# 36                                                   NaN   53.0       8.0
# 148    Base de datos con las entidades financieras en...   60.0      10.0
# 359    Corregidores y Auxiliares o Ayudantes de Corre...   54.0       9.0
# 530    Lista de zonas wifi en el departamento de Casa...   58.0       8.0
# 826    Registro de vallas publicitarias del Municipio...   53.0       8.0
# ...                                                  ...    ...       ...
# 39744  Datos relacionados a la Producción Agrícola de...   52.0      10.0
# 39798  Información de las empresas constructoras que ...   57.0       8.0
# 39835  Docentes de planta, contrato y catedráticos cl...   59.0       8.0
# 40082  Conozca indicadores de economía y productivida...   57.0      10.0
# 40085  Tarifas de acueducto y alcantarillado, haciend...   60.0      10.0
#
# [122 rows x 5 columns]

# %% [markdown]
# #### Ejemplo: búsqueda por fecha

# %% [markdown]
# La tabla de inventario también puede filtrase por fecha. Para hacerlo, se ingresa el diccionario de filtro con una de las columnas de fecha y se especifican las fechas de inicio y de fin deseadas. El siguiente ejemplo muestra cómo obtener la tabla de inventario para publicaciones creadas entre el 1 de enero de 2020 y el 1 de febrero de 2020.

# %%
# Se crea el diccionario con el filtro deseado
filtro = {
    "fecha_creacion": ["2020-01-01", "2020-02-01"],
}

# Se abre la tabla de inventario con el filtro deseado
inventario = DatosGov().tabla_inventario(filtro=filtro)

# %%
# Se muestra la tabla filtrada por fecha
inventario
# Out:
#         numero_api                                             nombre  \
# 161      dva5-spdw  Casos importados de sarampión según entidad te...
# 320      ng69-pr5i                          Caudal Rio Chinchina 2016
# 321      fitj-g26r                       Centros de relevo - Llamadas
# 595      3iv5-72ms          VEINTE PRIMERAS CAUSAS DE MORBILIDAD 2019
# 803    yvci-wdre:0  Atención al Usuario año 2019 Instituto Municip...
# ...            ...                                                ...
# 38730    j2qs-kbnj                 HUMEDALES DEL MUNICIPIO DE PEDRAZA
# 39148  ks74-rcfu:1               Cuadro Clasificación Documental CENS
# 39155  dnmb-8bgm:0  Integrantes de la Mesa de participación efecti...
# 39932    9et2-bf5i                                   Entrega y Retoma
# 40116    etwv-wj8f            Pueblos indígenas a nivel Nacional 2020
#
#                                              descripcion  \
# 161    Contiene la estadística de los Casos importado...
# 320    Registro año 2016 de Caudales medios diarios d...
# 321                         Centros de relevo - Llamadas
# 595    VEINTE PRIMERAS CAUSAS DE MORBILIDAD POR CATEG...
# 803                                                  NaN
# ...                                                  ...
# 38730  El municipio de Pedraza se encuentra rodeado d...
# 39148               Cuadro Clasificación Documental CENS
# 39155                                                NaN
# 39932                                   Entrega y Retoma
# 40116  Información de la ubicación de los pueblos ind...
#
#                                                    dueno base_publica  \
# 161                              GOBERNACIÓN DEL CAQUETÁ           Si
# 320                           Aguas Manizales S.A. E.S.P           Si
# 321     Ministerio TIC Oficina TI Gestión de Informacion           Si
# 595    ESE Hospital Departamental Universitario Santa...           Si
# 803                                                    Y           No
# ...                                                  ...          ...
# 38730                  sistemas@pedraza-magdalena.gov.co           Si
# 39148                                     CENS Grupo EPM           No
# 39155                                      ALCALEJANDRIA           No
# 39932   Ministerio TIC Oficina TI Gestión de Informacion           Si
# 40116                            Ministerio del Interior           Si
#
#                     tipo                         categoria  \
# 161    conjunto de datos           Estadísticas Nacionales
# 320    conjunto de datos  Ambiente y Desarrollo Sostenible
# 321    conjunto de datos  Ciencia, Tecnología e Innovación
# 595    conjunto de datos         Salud y Protección Social
# 803    conjunto de datos                               NaN
# ...                  ...                               ...
# 38730  conjunto de datos  Ambiente y Desarrollo Sostenible
# 39148  conjunto de datos                   Minas y Energía
# 39155  conjunto de datos                               NaN
# 39932  conjunto de datos  Ciencia, Tecnología e Innovación
# 40116  conjunto de datos                               NaN
#
#                                           terminos_clave  \
# 161                                                  NaN
# 320                                          caudal,agua
# 321                                                  NaN
# 595                                                  NaN
# 803                                                  NaN
# ...                                                  ...
# 38730                                  humedales,cienaga
# 39148  cuadros de clasificación documental,centrales ...
# 39155                                                NaN
# 39932                                                NaN
# 40116                     etnias,dairm,pueblos,indígenas
#
#                                                     url      fecha_creacion  \
# 161                https://www.datos.gov.co/d/dva5-spdw 2020-01-15 14:51:43
# 320                https://www.datos.gov.co/d/ng69-pr5i 2020-01-03 14:37:23
# 321                https://www.datos.gov.co/d/fitj-g26r 2020-01-27 19:38:45
# 595                https://www.datos.gov.co/d/3iv5-72ms 2020-01-31 20:30:52
# 803    https://www.datos.gov.co/d/yvci-wdre/revisions/0 2020-01-02 15:41:58
# ...                                                 ...                 ...
# 38730              https://www.datos.gov.co/d/j2qs-kbnj 2020-01-09 13:25:16
# 39148  https://www.datos.gov.co/d/ks74-rcfu/revisions/1 2020-01-22 14:55:12
# 39155  https://www.datos.gov.co/d/dnmb-8bgm/revisions/0 2020-01-16 17:18:02
# 39932              https://www.datos.gov.co/d/9et2-bf5i 2020-01-27 21:17:01
# 40116              https://www.datos.gov.co/d/etwv-wj8f 2020-01-27 14:47:31
#
#        ...                                            entidad  \
# 161    ...                     Boletín Epidemiológico Semanal
# 320    ...                      Aguas de Manizales S.A. E.S.P
# 321    ...  Ministerio de Tecnologías de la Información y ...
# 595    ...                                                NaN
# 803    ...                                                NaN
# ...    ...                                                ...
# 38730  ...                                              UMATA
# 39148  ...                                   CENS S.A. E.S.P.
# 39155  ...                                                NaN
# 39932  ...  Ministerio de Tecnologías de la Información y ...
# 40116  ...                            Ministerio del Interior
#
#                                              entidad_url  \
# 161                                                  NaN
# 320                                                  NaN
# 321                    https://colombiatic.mintic.gov.co
# 595                                                  NaN
# 803                                                  NaN
# ...                                                  ...
# 38730  http://www.pedraza-magdalena.gov.co/directorio...
# 39148  https://www.cens.com.co/Portals/Contingencia/l...
# 39155                                                NaN
# 39932                  https://colombiatic.mintic.gov.co
# 40116               https://www.datos.gov.co/d/etwv-wj8f
#
#                          entidad_sector entidad_departamento entidad_orden  \
# 161                        Estadísticas              Caquetá      Nacional
# 320    Ambiente y Desarrollo Sostenible               Caldas   Territorial
# 321    Ciencia, Tecnología e innovación          Bogotá D.C.      Nacional
# 595           Salud y Protección Social               Caldas   Territorial
# 803                                 NaN                  NaN           NaN
# ...                                 ...                  ...           ...
# 38730  Ambiente y Desarrollo Sostenible            Magdalena   Territorial
# 39148                   Minas y Energía   Norte de Santander   Territorial
# 39155                               NaN                  NaN           NaN
# 39932  Ciencia, Tecnología e innovación          Bogotá D.C.      Nacional
# 40116                          Interior          Bogotá D.C.      Nacional
#
#                                  entidad_dependencia entidad_municipio  \
# 161                             Dirección de las TIC         Florencia
# 320                                  Recurso Hidrico         Manizales
# 321                        Dirección de Apropiación        Bogotá D.C.
# 595                         Planeación e Información         Manizales
# 803                                              NaN               NaN
# ...                                              ...               ...
# 38730                                          umata           Pedraza
# 39148     Unidad Suministro y Soporte Administrativo            Cúcuta
# 39155                                            NaN               NaN
# 39932             Dirección Computadores para Educar       Bogotá D.C.
# 40116  Dirección de Asuntos Indígenas ROM y Minorías       Bogotá D.C.
#
#       actualizacion_frecuencia   idioma      cobertura
# 161                    Trienio  Español       Nacional
# 320                      Anual  Español      Municipal
# 321                    Mensual  Español       Nacional
# 595                      Anual  Español  Departamental
# 803                        NaN      NaN            NaN
# ...                        ...      ...            ...
# 38730                Semestral  Español      Municipal
# 39148                    Anual  Español       Nacional
# 39155                      NaN      NaN            NaN
# 39932                  Mensual  Español       Nacional
# 40116                    Anual  Español       Nacional
#
# [101 rows x 25 columns]

# %% [markdown]
# ### Abrir un conjunto de datos del Portal de Datos Abiertos

# %% [markdown]
# Para abrir un conjunto de datos.gov.co es necesario tener el código API de ese conjunto e ingresarlo al método "cargar_base" de la clase DatosGov. Con esta función se crea un objeto que contiene el dataframe y el diccionario de metadatos del conjunto, los cuales se pueden obtener con los métodos "to_dataframe" y "metadatos"
#
# Abajo está el código para cargar el conjunto de datos de "Pueblos indígenas a nivel Nacional 2020", el cual se encuentra en el último filtro de la tabla de inventario.

# %% [markdown]
# #### Cargar conjunto de datos con número API

# %%
# Se define la variable "numero_api", que contiene el número API del conjunto "Pueblos indígenas a nivel Nacional 2020"
numero_api = "etwv-wj8f"
# Se descarga la información del conjunto de datos en la variable "data" con el método "cargar_base". 
# Al parámetro "api_id" se asigna el número API y "limite_filas" especifica que únicamente se descargan 200 filas del conjunto
data = DatosGov().cargar_base(api_id = numero_api, limite_filas=200)

# %% [markdown]
# #### Obtener dataframe del conjunto de datos

# %%
# Se obtiene el dataframe del conjunto de datos con el método "to_dataframe"
datos = data.to_dataframe()
# Se visualiza una versión reducida del dataframe
datos
# Out:
#      unnamed_column     departamento  pueblos_indigenas
# 0               NaN         AMAZONAS           KAWIYARI
# 1               NaN         AMAZONAS              SIONA
# 2               NaN         AMAZONAS              YAGUA
# 3               NaN         AMAZONAS           BARASANO
# 4               NaN         AMAZONAS            LETUAMA
# ..              ...              ...                ...
# 195             NaN  VALLE DEL CAUCA       EMBERA CHAMI
# 196             NaN  VALLE DEL CAUCA  EPERARA SIAPIDARA
# 197             NaN  VALLE DEL CAUCA               NASA
# 198             NaN  VALLE DEL CAUCA              PASTO
# 199             NaN  VALLE DEL CAUCA            WAUNANN
#
# [200 rows x 3 columns]

# %% [markdown]
# #### Obtener diccionario de metadatos del conjunto de datos

# %%
# Los metadatos se obtienen con el método "metadatos" y se asignan a la variable "meta"
meta = data.metadatos()
# Se visualiza el diccionario de metadatos
meta
# Out:
# {'numero_api': 'etwv-wj8f',
#  'nombre': 'Pueblos indígenas a nivel Nacional 2020',
#  'descripcion': 'Información de la ubicación de los pueblos indígenas por departamento y municipio a 31 de Diciembre de 2020.',
#  'tipo': 'dataset',
#  'url': 'https://www.datos.gov.co/d/etwv-wj8f',
#  'categoria': 'NA',
#  'fecha_creacion': '2020-01-27',
#  'numero_vistas': 622,
#  'numero_descargas': 110,
#  'licencia': 'Creative Commons Attribution | Share Alike 4.0 International',
#  'fecha_publicacion': '2020-01-27',
#  'base_publica': 'published',
#  'fecha_actualizacion': '2021-01-26',
#  'numero_filas': 226,
#  'numero_columnas': 3,
#  'licencia_url': 'http://creativecommons.org/licenses/by-sa/4.0/legalcode',
#  'entidad': 'Ministerio del Interior',
#  'entidad_municipio': 'Bogotá D.C.',
#  'entidad_sector': 'Interior',
#  'entidad_departamento': 'Bogotá D.C.',
#  'entidad_orden': 'Nacional',
#  'entidad_dependencia': 'Dirección de Asuntos Indígenas ROM y Minorías',
#  'cobertura': 'Nacional',
#  'idioma': 'Español',
#  'frecuencia_actualizacion': 'Anual',
#  'dueno': 'Ministerio del Interior',
#  'columnas': {'Unnamed Column': {'tipo': 'text',
#    'descripcion': '',
#    'nombre_df': 'unnamed_column'},
#   'DEPARTAMENTO': {'tipo': 'text',
#    'descripcion': '',
#    'nombre_df': 'departamento'},
#   'PUEBLOS INDIGENAS': {'tipo': 'text',
#    'descripcion': '',
#    'nombre_df': 'pueblos_indigenas'}}}
